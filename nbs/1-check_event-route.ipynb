# %%
import requests

version = "v1"
path = f"/api/{version}/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"

response = requests.get(endpoint)

print(response.ok)
# Out:
# True

# %%
import requests

version = "v1"
path = f"/api/{version}/events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"

response = requests.get(endpoint)

if response.ok:
    result = response.json()
    print(result)
# Out:
# {'results': [{'id': 1}, {'id': 2}, {'id': 3}], 'count': 6}

# %%
import requests

version = "v1"
path = f"/api/{version}/events/10"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"

response = requests.get(endpoint)

if response.ok:
    result = response.json()
    print(result)
# Out:
# {'id': 10}
